# %%
x = 4
x1 = 9
x2 = 5

print((((2+5)*3)+x+5) < x1)
print(((2+5)*3)+ (x+5 < x1) == (x == 6+x2*2))
print(((3*6) + x - 3) < x2)
print(((7*8)>(x+4 > x1)<(x!= 2+x2*9)))
# Out:
# False
# False
# False
# True

# %%
#N fora do intervalo entre 20 e 30
n=int(input())
print(not(n > 20 and n < 30))
print(n<=20 or n >= 30)
# Out:
# 25
# False
# False

# %%
A=int(input())
B=int(input())
if A > 10 and B <= 5:
  print("sim")
# Out:
# 11
# 5
# sim

# %%
a=int(input())
b=int(input())
print(not(a >= 10 or b < 5))
print(a<10 and b >= 5)
# Out:
# 10
# 10
# False
# False
