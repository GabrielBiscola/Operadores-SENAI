# %%
#Operadores
contas=[6+4*2, (4*9+5), ((6+7)), (15+20-30), (6+5**2)]
for x in contas:
  print("x"+str(contas.index(x)+1),"=", x)
# Out:
# x1 = 14
# x2 = 41
# x3 = 13
# x4 = 5
# x5 = 31

# %%
x=8
x+=5
x-=4
x*=20
x/=2
print(x)
# Out:
# 90.0

# %%
#Atribuição
x=8
print(x)
x+=5
print(x)
x=8
print(x)
x-=4
print(x)
x=8
print(x)
x*=20
print(x)
x=8
print(x)
x/=2
print(x)
# Out:
# 8
# 13
# 8
# 4
# 8
# 160
# 8
# 4.0

# %%
#Comparação
x=8
x1=3
results = [x<x1, x==x1, x>=x1, x!=x1]
for i in results:
  print(i)
# Out:
# False
# False
# True
# True

# %%
#Identidade
a = "botafogo"
b = "flamengo"
c = "botafogo"
print(a is c)
print(a is not b)
print(a is b)
print(b is not c)
# Out:
# True
# True
# False
# True

# %%
a = "botafogo"
b = "flamengo"
c = "botafogo"
lista = [a is c, a is not b, a is b, b is not c]
for i in lista:
  print(i)
# Out:
# True
# True
# False
# True

# %%
#Associação
frutas = ["banana", "laranja", "uva", "ameixa"]
x1 = "banana"
x2 = "laranja"
x3 = "abacaxi"

print(x1 in frutas)
print(x1 not in frutas)
print(x2 in frutas)
print(x3 in frutas)
# Out:
# True
# False
# True
# False
